# %%
library("ggplot2")

# %%
cp = ggplot(mtcars, aes(x = factor(cyl))) + 
geom_bar(color = "white", fill = "blue") + 
theme_bw(base_size = 14)

cp
# Out:
# plot without title

# %%
ggplot(mtcars, aes(x = gear, fill = factor(carb))) + 
geom_bar() + 
theme_bw(base_size = 14)
# Out:
# plot without title

# %%
supp = c("VC", "VC", "VC", "OJ", "OJ", "OJ")
dose = c("D0.5", "D1", "D2", "D0.5", "D1", "D2")
len = c(6.8, 15.0, 33.0, 4.2, 10.0, 29.5)

df2 = data.frame(supp, dose, len, stringsAsFactors = FALSE)

# %%
# Stacked barplot with multiple groups
ggplot(data = df2, aes(x = dose, y = len, fill = supp)) + 
geom_bar(stat = "identity") + 
theme_bw(base_size = 14)
# Out:
# plot without title

# %%
# Use position = 'dodge'
ggplot(data = df2, aes(x = dose, y = len, fill = supp)) + 
geom_bar(stat = "identity", position = 'dodge') + 
theme_bw(base_size = 14)
# Out:
# plot without title
