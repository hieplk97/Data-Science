# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

# %%
img = Image.open('face.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=333x337 at 0x1D91CCA8490>

# %%
img_arr = np.array(img)
img_arr.shape
# Out:
# (337, 333, 3)

# %%
layer1 = img_arr[:,:,0]
layer1[130:140, 130:140]
# Out:
# array([[253, 253, 255, 255, 255, 255, 255, 255, 255, 255],
#        [252, 254, 255, 255, 255, 255, 255, 255, 255, 255],
#        [188, 255, 254, 255, 255, 255, 255, 255, 255, 255],
#        [103, 255, 253, 255, 255, 255, 255, 255, 255, 255],
#        [ 42, 221, 254, 252, 255, 255, 255, 255, 253, 255],
#        [ 27, 161, 255, 252, 255, 254, 255, 255, 255, 255],
#        [ 26,  97, 253, 254, 252, 255, 254, 254, 255, 255],
#        [ 32,  52, 239, 253, 253, 255, 255, 254, 255, 255],
#        [ 34,  36, 204, 253, 255, 255, 255, 255, 255, 255],
#        [ 36,  26, 161, 254, 253, 255, 255, 255, 255, 255]], dtype=uint8)

# %%
layer2 = img_arr[:,:,1]
layer2[130:140, 130:140]
# Out:
# array([[234, 226, 225, 224, 225, 225, 225, 225, 225, 225],
#        [227, 229, 225, 225, 225, 226, 226, 225, 225, 225],
#        [167, 233, 227, 225, 225, 225, 225, 225, 225, 225],
#        [ 97, 233, 226, 225, 226, 225, 225, 225, 225, 225],
#        [ 42, 197, 232, 225, 226, 226, 225, 224, 226, 225],
#        [ 26, 142, 235, 226, 225, 224, 225, 225, 224, 225],
#        [ 25,  89, 227, 229, 225, 225, 227, 224, 225, 225],
#        [ 31,  53, 211, 228, 225, 225, 225, 224, 225, 225],
#        [ 34,  38, 182, 233, 225, 225, 225, 226, 225, 225],
#        [ 36,  30, 147, 239, 223, 225, 225, 225, 224, 225]], dtype=uint8)

# %%
layer3 = img_arr[:,:,2]
layer3[130:140, 130:140]
# Out:
# array([[52, 49, 51, 51, 51, 51, 51, 51, 51, 51],
#        [49, 51, 49, 51, 51, 52, 52, 51, 51, 51],
#        [48, 55, 50, 51, 51, 51, 51, 51, 51, 51],
#        [37, 52, 49, 51, 52, 51, 49, 51, 51, 51],
#        [40, 47, 51, 50, 47, 52, 51, 53, 49, 51],
#        [31, 47, 51, 51, 51, 50, 53, 51, 51, 51],
#        [33, 42, 52, 49, 46, 51, 52, 50, 49, 51],
#        [37, 39, 49, 50, 53, 51, 51, 52, 51, 51],
#        [34, 33, 45, 50, 51, 49, 49, 52, 49, 51],
#        [34, 33, 50, 50, 49, 56, 51, 53, 51, 51]], dtype=uint8)

# %%
from sklearn.preprocessing import Binarizer

# %%
thre = 128
scaler = Binarizer(threshold=thre)

# %%
layer1_bin = scaler.fit_transform(layer1)
layer1
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
lst = []
lst.append(layer1_bin)
lst.append(layer2)
lst.append(layer3)
