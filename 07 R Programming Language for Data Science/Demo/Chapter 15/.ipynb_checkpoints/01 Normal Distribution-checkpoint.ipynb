# %%
# Create a sequence of numbers between -10 and 10 incrementing by 0.1
x = seq(-10 , 10, by = 0.1)

# %%
# Choose the mean as 0 and standard deviation as 1
y = dnorm(x, mean = 0, sd = 1)

# %%
plot(x, y)
# Out:
# plot without title

# %%
# Choose the mean as 0 and standard deviation as 1
y = pnorm(x, mean = 0, sd = 1)

# %%
plot(x, y)
# Out:
# plot without title

# %%
# Create a sequence of probability values incrementing by 0.02
x = seq(0, 1, by = 0.02)

# %%
# Choose the mean as 0 and standard deviation as 1
y = qnorm(x, mean = 0, sd = 1)

# %%
plot(x, y)
# Out:
# plot without title

# %%
# Create a sample of 50 numbers which are normally distributed
y = rnorm(50)
print(y)
# Out:
#  [1]  0.93536408  0.73822329  1.14722687  2.01639253 -1.30917408  0.10595282
#  [7]  0.83622321 -0.86402145 -1.08020278  0.90155835 -0.19008024 -1.51380471
# [13]  0.87510890  0.59203661  1.22620795 -1.43058770 -0.40932650 -0.55282318
# [19] -1.77108264  1.32383334  1.13998357 -0.03692467  0.69745716 -1.38737010
# [25]  0.61952009  0.66631115  0.93898527 -0.70443473 -1.75545778 -1.62439470
# [31] -1.55962494 -0.02354115  1.42299605  2.27481562  2.65961012  0.63428659
# [37] -1.34800389 -0.07874075 -1.33945358 -0.99576098  1.26149259  0.13414885
# [43]  0.62587987 -1.21316955 -0.06088927  1.61637514  0.02514746  0.20384822
# [49] -2.21627233 -0.80617832

# %%
hist(y, main = "Normal Distribution")
# Out:
# Plot with title "Normal Distribution"
