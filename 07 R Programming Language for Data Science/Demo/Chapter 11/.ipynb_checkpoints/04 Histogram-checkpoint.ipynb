# %%
v = c(36, 25, 38, 46, 55, 68, 72, 55, 36, 38, 67, 45, 22, 48, 91, 46, 52, 61, 58, 55)

# %%
hist(v, main = "Histogram of V", xlab = "Age", col = "orange")
# Out:
# Plot with title "Histogram of V"

# %%
hist(v, main = "Histogram of V", xlab = "Age", col = "orange",
     xlim = c(0, 100), ylim = c(0, 5), border = "blue", breaks = 5)
# Out:
# Plot with title "Histogram of V"
