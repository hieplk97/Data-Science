# %%
head(airquality)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1 41    190      7.4 67   5     1
# 2 36    118      8.0 72   5     2
# 3 12    149     12.6 74   5     3
# 4 18    313     11.5 62   5     4
# 5 NA     NA     14.3 56   5     5
# 6 28     NA     14.9 66   5     6

# %%
temp = airquality$Temp

# %%
h = hist(temp,
         ylim = c(0,40), 
         xlim = c(50, 100),
         breaks = 7,
         col ="light blue")
text(h$mids,h$counts,labels=h$counts, adj=c(0.5, -0.5))
# Out:
# Plot with title "Histogram of temp"

# %%
hist(temp, main = "Maximum daily temperature at La Guardia Airport",
     xlab = "Temperature in degrees Fahrenheit",
     xlim = c(50,100),
     col = "chocolate",
     border = "brown",
     breaks = c(55,60,70,75,80,90,100))
# Out:
# Plot with title "Maximum daily temperature at La Guardia Airport"

# %%
hist(temp, main = "Maximum daily temperature at La Guardia Airport", xlab = "Temperature in degrees Fahrenheit",
    xlim = c(50,100), breaks = c(55,60,70,75,80,100))
# Out:
# Plot with title "Maximum daily temperature at La Guardia Airport"
