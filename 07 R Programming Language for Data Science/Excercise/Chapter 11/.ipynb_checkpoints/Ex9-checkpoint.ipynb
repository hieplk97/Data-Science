# %%
plot(x = faithful$eruptions, y = faithful$waiting, xlab = "eruptions", ylab = "waiting", main = "eruptions vs waiting")
# Out:
# Plot with title "eruptions vs waiting"

# %%
plot(x = faithful$eruptions, y = faithful$waiting, 
     xlab = "eruptions", ylab = "waiting", main = "eruptions vs waiting", frame = FALSE)
abline(lm(eruptions~waiting, data = faithful), col = "blue")
# Out:
# Plot with title "eruptions vs waiting"
